# %%
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

# Определить корни

# Найти интервалы, на которых функция возрастает

# Найти интервалы, на которых функция убывает

# Построить график

# Вычислить вершину

# Определить промежутки, на котором f > 0

# Определить промежутки, на котором f < 0

# %%
from sympy import *
from sympy.abc import x, a
from sympy import sin, pi
from sympy import cos, pi
from sympy import S, Interval, oo

# %%
# Корни
from sympy.abc import x, a
from sympy import sin, pi
from sympy import cos, pi
# ans = sympy.solve(-12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30)
ans = Eq(-12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30, 0)
# anz = sympy.solveset(ans, x, domain = S.Reals)
anz = solveset(Eq(-12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30, 0))
anz
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes)

# %%
import matplotlib.pyplot as plt

x = [(-12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30) for x in range(-10,10)]
y = [y for y in range(-10,10)]
plt.plot(x, y, 'ro')
plt.show()

# %%
# График
import matplotlib.pyplot as plt

x = [(-12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30) for x in range(-10,10)]
y = [y for y in range(-10,10)]

fig = plt.figure()
ax_3 = fig.add_subplot(2, 2, 4)
ax_3.plot(y, x)
ax_3.grid(axis = 'both')
fig.set_figwidth(12)
fig.set_figheight(12)

plt.show()

# %%
# Возростает
from sympy import S, Interval, oo
from sympy import is_decreasing, is_increasing
from sympy.abc import x, y

is_increasing(-12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30, Interval.open(8, oo))

# %%
# Убывает
from sympy import S, Interval, oo
from sympy import is_decreasing, is_increasing
from sympy.abc import x, y

is_decreasing(-12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30, Interval.open(-oo, -7))

# %%
from sympy import *
import numpy as np

x = Symbol('x')
y = -12*x**4*sin(cos(x))- 18*x**3+5*x**2 + 10*x - 30

yprime = y.diff(x)
print(yprime)
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10
